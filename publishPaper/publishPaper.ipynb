# %%
import re
from bs4 import BeautifulSoup

paperId = 468

with open("中央大學電子報.html", "r", encoding="utf-8") as file:
    html_content = file.read()

# 定義要查找並取代的文字對
replacements = {
    r"http://localhost:8080/": "http://hakka.ncu.edu.tw/",
    r"./中央大學電子報_files/hits.php": "https://www.cutercounter.com/hits.php?id=hvxonank&nd=6&style=4", # 免費計數器
    r"./中央大學電子報_files/image": f"http://hakka.ncu.edu.tw/Hakka_ePaper/paper/paper{paperId}/img/image", # 圖片
    r"./中央大學電子報_files/TOP": f"http://hakka.ncu.edu.tw/Hakka_ePaper/paper/paper{paperId}/img/TOP",
    r"./中央大學電子報_files/facebook512.png": "http://hakka.ncu.edu.tw/Hakka_ePaper/paper/social/facebook512.png",
    r"./中央大學電子報_files/twitter512.png": "http://hakka.ncu.edu.tw/Hakka_ePaper/paper/social/twitter512.png",
    r"./中央大學電子報_files/line512.png": "http://hakka.ncu.edu.tw/Hakka_ePaper/paper/social/line512.png",
    r"./中央大學電子報_files": f"http://hakka.ncu.edu.tw/Hakka_ePaper/paper/paper{paperId}",
    r'<div class="col-sm-11 col-md-6 tl-left">': '<div class="col-sm-11 col-md-6 tl-left media-pic">',
    r"col-sm-11 col-md-6 tl-left align-items-center d-flex": "col-sm-11 col-md-6 tl-left align-items-center d-flex media-test"
    # 可以根據需要添加更多的替換對
}
for old_text, new_text in replacements.items():
    html_content = html_content.replace(old_text,new_text)

css_pattern = re.compile(r'\.cover-content \{[^}]+\}')
css_replacement = """.cover-content {
    margin: 17px 28px !important;
    display: block !important;
    content: "";
    clear: both;
    overflow: auto;
}
.media-pic {
    min-width: 280px;
    float: left;
}

.media-test {
    width: auto;
    min-width: 50%;
}
"""
html_content = css_pattern.sub(css_replacement, html_content)


# 將修改後的 HTML 寫回檔案
with open("中央大學電子報_modified.html", "w", encoding="utf-8") as file:
    file.write(html_content)

print("多對文字取代完成")
# Out:
# 多對文字取代完成

# %%
import difflib

# File paths
file1_path = 'D:\\HakkaNCU\\papers\\468_NCU\\中央大學電子報.html'
file2_path = 'D:\\HakkaNCU\\papers\\468_NCU\\中央大學電子報_modified.html'

# Read file contents
def read_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return file.readlines()

content1 = read_file(file1_path)
content2 = read_file(file2_path)

# Compare files and print differences
diff = difflib.unified_diff(content1, content2, fromfile='中央大學電子報.html', tofile='中央大學電子報_modified.html', lineterm='')

# Output the differences
diff_list = list(diff)
diff_list
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 12
#       9     with open(file_path, 'r', encoding='utf-8') as file:
#      10         return file.readlines()
# ---> 12 content1 = read_file(file1_path)
#      13 content2 = read_file(file2_path)
#      15 # Compare files and print differences
#
# Cell In[2], line 9, in read_file(file_path)
#       8 def read_file(file_path):
# ----> 9     with open(file_path, 'r', encoding='utf-8') as file:
#      10         return file.readlines()
#
# File c:\Users\WMlab\.pyenv\pyenv-win\versions\3.10.10\lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/data/中央大學電子報.html'
